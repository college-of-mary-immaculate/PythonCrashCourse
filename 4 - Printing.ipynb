# %% [markdown]
# # Printing

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Welcome" "to" "CMI!")
# Out:
# WelcometoCMI!

# %%
print("Welcome", "to", "CMI!")
# Out:
# Welcome to CMI!

# %%
print("Hello, %s!" % ("Student"))
# Out:
# Hello, Student!

# %%
name = "John"
print("Hello", name, "!")
# Out:
# Hello John !

# %%
name = "John"
print("Hello, %s!" % (name))
# Out:
# Hello, John!

# %%
name = "John"
print(f"Hello, {name}!")
# Out:
# Hello, John!
